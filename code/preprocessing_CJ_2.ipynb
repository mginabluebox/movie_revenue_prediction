# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Term_Project_Unsupervised_Learners/data/"
path = "/content/drive/My Drive/Term_Project_Unsupervised_Learners/data/"

# %%
original = pd.read_csv(path+'aggregated.csv')

# %%
original.head()
# Out:
#       id  ...                                               crew
# 0    862  ...  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1   8844  ...  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  15602  ...  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  31357  ...  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  11862  ...  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 26 columns]

# %%
movie = pd.read_csv(path+'aggregated_1119.csv')
movie.id = movie['id.1.1'].astype('int')
movie.drop(['id.1','id.1.1'],axis = 1,inplace=True)
movie.head()

# %%
# convert list 
prd_countries = movie['production_countries'].tolist()
for i in movie[movie['production_countries'].notnull()].index: 
    if type(movie['production_countries'][i]) is not list:
        prd_countries[i] = ast.literal_eval(movie['production_countries'][i])

# %%
prd_count = pd.DataFrame(prd_countries)
prd_count['id'] = movie['id']

# %%
usa = []
for idx in prd_count.index:
    mov = prd_count.loc[idx]
    count = 0
    for i in mov.index:
        if type(mov[i]) == dict:
            if mov[i]['iso_3166_1'] == 'US':
                count +=1
    if count > 0:
        usa.append(True)
    else: usa.append(False)
movie['usa'] = usa
movie_us_only = movie.iloc[usa]

# %%
temp = original.set_index('id').loc[movie_us_only.set_index('id').index][['adult','video','revenue']]
movie_us_only.reset_index(inplace=True,drop=True)

# %%
movie_us_only['log_revenue_num'] = movie_us_only['revenue']
movie_us_only['adult'] = temp['adult'].values
movie_us_only['video'] = temp['video'].values
movie_us_only['revenue'] = temp['revenue'].values
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
movie_us_only['adult1'] = temp['adult']
movie_us_only['video1'] = temp['video'].values
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
movie_us_only.shape
# Out:
# (5619, 29)

# %%
movie_pd_companies = pd.read_csv(path+'aggregated_pd_companies.csv',index_col = None)
movie_pd_companies
# Out:
#         id  ...  production_company_class
# 0        0  ...                     minor
# 1        1  ...                    medium
# 2        2  ...                     major
# 3        3  ...                     minor
# 4        4  ...                    medium
# ...    ...  ...                       ...
# 5614  5614  ...                     minor
# 5615  5615  ...                     minor
# 5616  5616  ...                    medium
# 5617  5617  ...                     major
# 5618  5618  ...                     minor
#
# [5619 rows x 33 columns]

# %%
movie_us_only['first_company'] = movie_pd_companies['first_company']
movie_us_only['production_company_class'] = movie_pd_companies['production_company_class']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# movie_us_only.to_csv(path+'aggregated_us_only.csv')
# movie_us_only.to_csv(path+'aggregated_aggregated.csv',index=False)

# %%
movie_us_only
# Out:
#           id  ...  production_company_class
# 0        862  ...                     minor
# 1       8844  ...                    medium
# 2      31357  ...                     major
# 3      11862  ...                     minor
# 4        949  ...                    medium
# ...      ...  ...                       ...
# 5614  429200  ...                     minor
# 5615  269795  ...                     minor
# 5616  353491  ...                    medium
# 5617  378236  ...                     major
# 5618  395834  ...                     minor
#
# [5619 rows x 32 columns]
